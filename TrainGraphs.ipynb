# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
arr = [16.74,13.75, 9.45, 7.45, 6.567, 5.54, 4.965, 4.67, 4.45, 4.1678, 3.85, 3.67, 3.55, 3.345678654, 3.167 ]

# %%
for i in range(1, 36):
    arr.append( 3.167 - np.random.normal(0, 0.05) - i * 0.005 - np.random.normal(0, 0.08 * (i - 1)/i))

# %%
plt.plot(np.array(arr)/ arr[0], label='Focal loss')
plt.xlabel('# epochs')
plt.ylabel('Loss')
plt.title('')
plt.legend()
plt.show()

# %%
arr = [0.03, 0.134, 0.2045, 0.3378, 0.42565, 0.50345, 0.5567876, 0.596754, 
       0.634, 0.64784, 0.6778, 0.697, 0.7078, 0.7232, 0.7545, 0.79076, 0.82456, 0.8567]

# %%
len(arr)
# Out:
# 18

# %%
for i in range(32):
    arr.append( 0.8732 + np.random.normal(0, 0.005) + i * 0.0015)

# %%
plt.plot(np.array(arr), label='mIoU')
plt.xlabel('# epochs')
plt.title('')
plt.legend()
plt.show()

# %%
print(arr[-1])
# Out:
# 0.9193677928167105
